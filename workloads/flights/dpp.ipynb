# %%
import pandas as pd

data = pd.read_csv('flights-2048.csv')
data.head()
# Out:
#   airlineid sairportid dairportid  codeshare eq1 eq2 eq3 eq4 eq5 eq8  ...  \
# 0     '410'     '2965'     '2990'          0   f   f   f   f   f   f  ...
# 1     '410'     '2966'     '2990'          0   f   f   f   f   f   f  ...
# 2     '410'     '2966'     '2962'          0   f   f   f   f   f   f  ...
# 3     '410'     '2968'     '2990'          0   f   f   f   f   f   f  ...
# 4     '410'     '2968'     '4078'          0   f   f   f   f   f   f  ...
#
#    slatitude slongitude stimezone sdst            dcity dcountry  dlatitude  \
# 0  43.449928  39.956589         4    N            Kazan   Russia  55.606186
# 1  46.283333  48.006278         4    N            Kazan   Russia  55.606186
# 2  46.283333  48.006278         4    N  Mineralnye Vody   Russia  44.225072
# 3  55.305836  61.503333         4    N            Kazan   Russia  55.606186
# 4  55.305836  61.503333         4    N      Novosibirsk   Russia  55.012622
#
#   dlongitude dtimezone ddst
# 0  49.278728         4    N
# ...

# %%
unique_values = data.apply(lambda x: x.unique())
print(unique_values)

unique_counts = data.nunique()
print(unique_counts)
# Out:
# airlineid     ['410', '1654', '8359', '470', '1338', '2750',...
# sairportid    ['2965', '2966', '2968', '4029', '6156', '2922...
# dairportid    ['2990', '2962', '4078', '6969', '6160', '2952...
# codeshare                                                [0, 1]
# eq1                                                         [f]
# eq2                                                         [f]
# eq3                                                         [f]
# eq4                                                         [f]
# eq5                                                         [f]
# eq8                                                         [f]
# eq12                                                        [f]
# eq14                                                        [f]
# eq15                                                        [f]
# eq17                                                        [f]
# eq19                                                        [f]
# ...
